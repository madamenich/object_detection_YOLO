# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix



def compute_confusion_matrix(total_count, duplicate, misclassification):
    '''
    Compute a confusion matrix using numpy for two np.arrays
    '''

    # Provided values
    # total_count = 76
    # duplicate = 7
    # misclassification = 4
    
    # Calculate True Positives, False Positives, True Negatives, and False Negatives
    true_positive = total_count - duplicate - misclassification
    false_positive = duplicate
    true_negative = 0   # Assume there are no objects that were not detected
    false_negative = misclassification
    
    # Create the confusion matrix
    conf_matrix = np.array([[true_negative, false_positive],
                            [false_negative, true_positive]])
    
    # Display the confusion matrix using seaborn
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", 
                xticklabels=["Predicted Negative", "Predicted Positive"],
                yticklabels=["Actual Negative", "Actual Positive"])
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()

# %%
## Test Image 1, 4  x4
compute_confusion_matrix(76, 7, 2)

# %%
## Confusion Matrix of 6x6
compute_confusion_matrix(84,12,11)

# %%
## Confusion Matrix of 8x8
compute_confusion_matrix(98, 19, 12)

# %%
# Import numpy library
import numpy as np

# Define the total count of objects, duplicated count and misclassification count
total_count = 76
duplicated_count = 7
misclassification_count = 2

# Define the true positives, false positives, false negatives and true negatives
tp = total_count - duplicated_count - misclassification_count # 67
fp = duplicated_count # 7
fn = misclassification_count # 2
tn = 0 # Assume there are no objects that were not detected

# Create the confusion matrix as a numpy array
confusion_matrix = np.array([[tp, fp], [fn, tn]])

# Print the confusion matrix
print(confusion_matrix)
# Out:
# [[67  7]
#  [ 2  0]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Define the counts
total_count = 76
duplicated_count = 7
misclassification_count = 2

# Calculate true positives
true_positives = total_count - duplicated_count - misclassification_count

# Define the labels
labels = ['True Positives', 'Duplicated', 'Misclassification', 'True Negatives']

# Create a confusion matrix
confusion_mat = np.array([[true_positives, duplicated_count],
                          [misclassification_count, 0]])

# Create a heatmap to visualize the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mat, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=['Detected', 'Not Detected'])
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Confusion Matrix for Object Detection')
plt.show()
